# %% [markdown]
# # Introduction
#
# Pandas provides various functions for reading and writing data in different file formats, making it convenient to work with diverse types of data sources. Common file formats include CSV, Excel, SQL, JSON, and more. Below are examples of reading and writing data using pandas:

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Reading CSV file

# %%
df = pd.read_csv('/content/drive/MyDrive/Python/Pandas/csv-file.csv')
df
# Out:
#     A   B   C   D
# 0   1   2   3   4
# 1   5   6   7   8
# 2   9  10  11  12
# 3  13  14  15  16
# 4  17  18  19  20

# %% [markdown]
# ### CSV Output

# %%
df.to_csv('output-csv-file',index=False)

# %% [markdown]
# ## Reading Excel file

# %%
pd.read_excel('/content/drive/MyDrive/Python/Pandas/excel-file.xlsx')
# Out:
#    Unnamed: 0   A   B   C   D
# 0           0   0   1   2   3
# 1           1   4   5   6   7
# 2           2   8   9  10  11
# 3           3  12  13  14  15

# %% [markdown]
# ### Excel Output

# %%
df.to_excel('output-excel-file.xlsx')

# %% [markdown]
# ## Reading HTML file

# %%
df = pd.read_html('https://en.wikipedia.org/wiki/Minnesota')

# %%
df[0]
# Out:
#                                             Minnesota  \
# 0                                               State
# 1   .mw-parser-output .ib-settlement-cols{text-ali...
# 2   Nicknames: Land of 10,000 Lakes; North Star St...
# 3   Motto: L'Étoile du Nord (French: The Star of t...
# 4                           Anthem: "Hail! Minnesota"
# 5   Map of the United States with Minnesota highli...
# 6                                             Country
# 7                                    Before statehood
# 8                               Admitted to the Union
# 9                                             Capital
# 10                                       Largest city
# 11                       Largest county or equivalent
# 12                      Largest metro and urban areas
# 13                                         Government
# 14                                         • Governor
# 15                              • Lieutenant Governor
# ...

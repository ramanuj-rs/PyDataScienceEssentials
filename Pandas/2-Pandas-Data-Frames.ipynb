# %% [markdown]
# # DataFrames
#
# A DataFrame in pandas is a two-dimensional, tabular data structure that organizes data into rows and columns. It is a powerful and versatile tool for data manipulation, analysis, and exploration in Python. The pandas DataFrame is similar to a spreadsheet or SQL table, offering labeled axes (rows and columns) with the flexibility to hold different types of data.

# %%
import pandas as pd
import numpy as np

# %%
from numpy.random import randn
np.random.seed(101)

# %%
df = pd.DataFrame(randn(6,5),index='A B C D E F'.split(),columns='V W X Y Z'.split())

# %%
df
# Out:
#           V         W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826  0.651118
# B -0.319318 -0.848077  0.605965 -2.018168  0.740122
# C  0.528813 -0.589001  0.188695 -0.758872 -0.933237
# D  0.955057  0.190794  1.978757  2.605967  0.683509
# E  0.302665  1.693723 -1.706086 -1.159119 -0.134841
# F  0.390528  0.166905  0.184502  0.807706  0.072960

# %% [markdown]
# ## Selection and Indexing

# %%
df['X']
# Out:
# A    0.907969
# B    0.605965
# C    0.188695
# D    1.978757
# E   -1.706086
# F    0.184502
# Name: X, dtype: float64

# %%
# Selecting multiple columns
df[['X','Y']]
# Out:
#           X         Y
# A  0.907969  0.503826
# B  0.605965 -2.018168
# C  0.188695 -0.758872
# D  1.978757  2.605967
# E -1.706086 -1.159119
# F  0.184502  0.807706

# %%
# SQL Syntax (Alterantive)
df.X
# Out:
# A    0.907969
# B    0.605965
# C    0.188695
# D    1.978757
# E   -1.706086
# F    0.184502
# Name: X, dtype: float64

# %%
type(df['X'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# **Creating a new column:**

# %%
df['New'] = df['X'] + df['Y']

# %%
df
# Out:
#           V         W         X         Y         Z       new       New
# A  2.706850  0.628133  0.907969  0.503826  0.651118  1.411795  1.411795
# B -0.319318 -0.848077  0.605965 -2.018168  0.740122 -1.412203 -1.412203
# C  0.528813 -0.589001  0.188695 -0.758872 -0.933237 -0.570177 -0.570177
# D  0.955057  0.190794  1.978757  2.605967  0.683509  4.584725  4.584725
# E  0.302665  1.693723 -1.706086 -1.159119 -0.134841 -2.865205 -2.865205
# F  0.390528  0.166905  0.184502  0.807706  0.072960  0.992208  0.992208

# %% [markdown]
# ** Removing Columns**

# %%
df.drop('New',axis=1)
# Out:
#           V         W         X         Y         Z       new
# A  2.706850  0.628133  0.907969  0.503826  0.651118  1.411795
# B -0.319318 -0.848077  0.605965 -2.018168  0.740122 -1.412203
# C  0.528813 -0.589001  0.188695 -0.758872 -0.933237 -0.570177
# D  0.955057  0.190794  1.978757  2.605967  0.683509  4.584725
# E  0.302665  1.693723 -1.706086 -1.159119 -0.134841 -2.865205
# F  0.390528  0.166905  0.184502  0.807706  0.072960  0.992208

# %%
# Not inplace till now
df
# Out:
#           V         W         X         Y         Z       new       New
# A  2.706850  0.628133  0.907969  0.503826  0.651118  1.411795  1.411795
# B -0.319318 -0.848077  0.605965 -2.018168  0.740122 -1.412203 -1.412203
# C  0.528813 -0.589001  0.188695 -0.758872 -0.933237 -0.570177 -0.570177
# D  0.955057  0.190794  1.978757  2.605967  0.683509  4.584725  4.584725
# E  0.302665  1.693723 -1.706086 -1.159119 -0.134841 -2.865205 -2.865205
# F  0.390528  0.166905  0.184502  0.807706  0.072960  0.992208  0.992208

# %%
df.drop('New',axis=1,inplace=True)

# %%
# Now permanently removed
df
# Out:
#           V         W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826  0.651118
# B -0.319318 -0.848077  0.605965 -2.018168  0.740122
# C  0.528813 -0.589001  0.188695 -0.758872 -0.933237
# D  0.955057  0.190794  1.978757  2.605967  0.683509
# E  0.302665  1.693723 -1.706086 -1.159119 -0.134841
# F  0.390528  0.166905  0.184502  0.807706  0.072960

# %% [markdown]
# ** Selecting Rows**

# %%
df.loc['A']
# Out:
# V    2.706850
# W    0.628133
# X    0.907969
# Y    0.503826
# Z    0.651118
# Name: A, dtype: float64

# %% [markdown]
# Select based on position instead of label

# %%
df.iloc[1]
# Out:
# V   -0.319318
# W   -0.848077
# X    0.605965
# Y   -2.018168
# Z    0.740122
# Name: B, dtype: float64

# %% [markdown]
# ** Selecting subset of rows and columns **

# %%
df.loc['A','Y']
# Out:
# 0.5038257538223936

# %%
df.loc[['A','B'],['W','X']]
# Out:
#           W         X
# A  0.628133  0.907969
# B -0.848077  0.605965

# %% [markdown]
# ### Conditional Selection

# %%
df
# Out:
#           V         W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826  0.651118
# B -0.319318 -0.848077  0.605965 -2.018168  0.740122
# C  0.528813 -0.589001  0.188695 -0.758872 -0.933237
# D  0.955057  0.190794  1.978757  2.605967  0.683509
# E  0.302665  1.693723 -1.706086 -1.159119 -0.134841
# F  0.390528  0.166905  0.184502  0.807706  0.072960

# %%
df>0
# Out:
#        V      W      X      Y      Z
# A   True   True   True   True   True
# B  False  False   True  False   True
# C   True  False   True  False  False
# D   True   True   True   True   True
# E   True   True  False  False  False
# F   True   True   True   True   True

# %%
df[df>0]
# Out:
#           V         W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826  0.651118
# B       NaN       NaN  0.605965       NaN  0.740122
# C  0.528813       NaN  0.188695       NaN       NaN
# D  0.955057  0.190794  1.978757  2.605967  0.683509
# E  0.302665  1.693723       NaN       NaN       NaN
# F  0.390528  0.166905  0.184502  0.807706  0.072960

# %%
df[df['W']>0]
# Out:
#           V         W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826  0.651118
# D  0.955057  0.190794  1.978757  2.605967  0.683509
# E  0.302665  1.693723 -1.706086 -1.159119 -0.134841
# F  0.390528  0.166905  0.184502  0.807706  0.072960

# %%
df[df['W']>0]['X']
# Out:
# A    0.907969
# D    1.978757
# E   -1.706086
# F    0.184502
# Name: X, dtype: float64

# %%
df[df['W']>0][['X','Y','Z']]
# Out:
#           X         Y         Z
# A  0.907969  0.503826  0.651118
# D  1.978757  2.605967  0.683509
# E -1.706086 -1.159119 -0.134841
# F  0.184502  0.807706  0.072960

# %% [markdown]
# For more than one condition either |(or) or &(and):

# %%
df[(df['W']>0) & (df['Y'] > 1)]
# Out:
#           V         W         X         Y         Z
# D  0.955057  0.190794  1.978757  2.605967  0.683509

# %% [markdown]
# ## More Index Details

# %%
df
# Out:
#           V         W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826  0.651118
# B -0.319318 -0.848077  0.605965 -2.018168  0.740122
# C  0.528813 -0.589001  0.188695 -0.758872 -0.933237
# D  0.955057  0.190794  1.978757  2.605967  0.683509
# E  0.302665  1.693723 -1.706086 -1.159119 -0.134841
# F  0.390528  0.166905  0.184502  0.807706  0.072960

# %%
# Reset to default index
df.reset_index()
# Out:
#   index         V         W         X         Y         Z
# 0     A  2.706850  0.628133  0.907969  0.503826  0.651118
# 1     B -0.319318 -0.848077  0.605965 -2.018168  0.740122
# 2     C  0.528813 -0.589001  0.188695 -0.758872 -0.933237
# 3     D  0.955057  0.190794  1.978757  2.605967  0.683509
# 4     E  0.302665  1.693723 -1.706086 -1.159119 -0.134841
# 5     F  0.390528  0.166905  0.184502  0.807706  0.072960

# %%
newindex = 'WB PN AS HP JK DL'.split()

# %%
df['States'] = newindex

# %%
df
# Out:
#           V         W         X         Y         Z States
# A  2.706850  0.628133  0.907969  0.503826  0.651118     WB
# B -0.319318 -0.848077  0.605965 -2.018168  0.740122     PN
# C  0.528813 -0.589001  0.188695 -0.758872 -0.933237     AS
# D  0.955057  0.190794  1.978757  2.605967  0.683509     HP
# E  0.302665  1.693723 -1.706086 -1.159119 -0.134841     JK
# F  0.390528  0.166905  0.184502  0.807706  0.072960     DL

# %%
df.set_index('States')
# Out:
#                V         W         X         Y         Z
# States
# WB      2.706850  0.628133  0.907969  0.503826  0.651118
# PN     -0.319318 -0.848077  0.605965 -2.018168  0.740122
# AS      0.528813 -0.589001  0.188695 -0.758872 -0.933237
# HP      0.955057  0.190794  1.978757  2.605967  0.683509
# JK      0.302665  1.693723 -1.706086 -1.159119 -0.134841
# DL      0.390528  0.166905  0.184502  0.807706  0.072960

# %%
df
# Out:
#           V         W         X         Y         Z States
# A  2.706850  0.628133  0.907969  0.503826  0.651118     WB
# B -0.319318 -0.848077  0.605965 -2.018168  0.740122     PN
# C  0.528813 -0.589001  0.188695 -0.758872 -0.933237     AS
# D  0.955057  0.190794  1.978757  2.605967  0.683509     HP
# E  0.302665  1.693723 -1.706086 -1.159119 -0.134841     JK
# F  0.390528  0.166905  0.184502  0.807706  0.072960     DL

# %%
df.set_index('States',inplace=True)

# %%
df
# Out:
#                V         W         X         Y         Z
# States
# WB      2.706850  0.628133  0.907969  0.503826  0.651118
# PN     -0.319318 -0.848077  0.605965 -2.018168  0.740122
# AS      0.528813 -0.589001  0.188695 -0.758872 -0.933237
# HP      0.955057  0.190794  1.978757  2.605967  0.683509
# JK      0.302665  1.693723 -1.706086 -1.159119 -0.134841
# DL      0.390528  0.166905  0.184502  0.807706  0.072960

# %% [markdown]
# ## Multi-Index and Index Hierarchy

# %%
outside = ['G1','G1','G1','G2','G2','G2'] # Outside Index
inside = [1,2,3,1,2,3] # Inside Index
hier_index = list(zip(outside,inside))
hier_index = pd.MultiIndex.from_tuples(hier_index)

# %%
hier_index
# Out:
# MultiIndex([('G1', 1),
#             ('G1', 2),
#             ('G1', 3),
#             ('G2', 1),
#             ('G2', 2),
#             ('G2', 3)],
#            )

# %%
df = pd.DataFrame(np.random.randn(6,3),index=hier_index,columns=['A','B','C'])
df
# Out:
#              A         B         C
# G1 1  2.154846 -0.610259 -0.755325
#    2 -0.346419  0.147027 -0.479448
#    3  0.558769  1.024810 -0.925874
# G2 1  1.862864 -1.133817  0.610478
#    2  0.386030  2.084019 -0.376519
#    3  0.230336  0.681209  1.035125

# %% [markdown]
# ## Indexing in Multi-index and Hierarchy

# %%
df.loc['G1']
# Out:
#           A         B         C
# 1  2.154846 -0.610259 -0.755325
# 2 -0.346419  0.147027 -0.479448
# 3  0.558769  1.024810 -0.925874

# %%
df.loc['G1'].loc[1]
# Out:
# A    2.154846
# B   -0.610259
# C   -0.755325
# Name: 1, dtype: float64

# %%
df.index.names
# Out:
# FrozenList([None, None])

# %%
df.index.names = ['Group','Num']

# %%
df
# Out:
#                   A         B         C
# Group Num
# G1    1    2.154846 -0.610259 -0.755325
#       2   -0.346419  0.147027 -0.479448
#       3    0.558769  1.024810 -0.925874
# G2    1    1.862864 -1.133817  0.610478
#       2    0.386030  2.084019 -0.376519
#       3    0.230336  0.681209  1.035125

# %%
df.xs('G1')
# Out:
#             A         B         C
# Num
# 1    2.154846 -0.610259 -0.755325
# 2   -0.346419  0.147027 -0.479448
# 3    0.558769  1.024810 -0.925874

# %%
df.xs(['G1',1])
# Out:
# <ipython-input-63-c549ee06ce91>:1: FutureWarning: Passing lists as key for xs is deprecated and will be removed in a future version. Pass key as a tuple instead.
#   df.xs(['G1',1])
# A    2.154846
# B   -0.610259
# C   -0.755325
# Name: (G1, 1), dtype: float64

# %%
df.xs(1,level='Num')
# Out:
#               A         B         C
# Group
# G1     2.154846 -0.610259 -0.755325
# G2     1.862864 -1.133817  0.610478
